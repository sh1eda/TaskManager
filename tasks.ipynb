# %%
import json
import os

def create_task(task_data: dict):
    filename = "tasks.json"
    if not os.path.exists(filename):
        ext_data = []
    else:
        try:
            with open(filename, "r") as f:
                ext_data = json.load(f)
        except json.JSONDecodeError:
            ext_data = []

    ext_data.append(task_data)

    with open(filename, "w") as f:
        json.dump(ext_data, f, indent=4)

    print("Task created successfully!")
    return ext_data


create_task({"task": "Learn Python", "status": "In Progress"})
# Out:
# Task created successfully!
# [{'task': 'Learn Python', 'status': 'In Progress'},
#  {'task': 'Learn Python', 'status': 'In Progress'},
#  {'task2': 'Learn Python', 'status': 'In Progress'}]

# %%
with open("tasks.json", "r") as f:
    tasks = json.load(f)
    for index, task in enumerate(tasks, start=1):
        name = task.get("task", "Unknown Task")
        status = task.get("status", "Not Started")
        print(f"Task - {index}: {name}, Task Status: {status}")
# Out:
# Task - 1: Learn Python, Task Status: In Progress
# Task - 2: Learn Python, Task Status: In Progress
# Task - 3: Unknown Task, Task Status: In Progress
